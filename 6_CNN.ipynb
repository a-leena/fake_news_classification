# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import ast
import pickle
from sklearn.model_selection import train_test_split
from gensim.models import Word2Vec
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Input, Embedding, Conv1D, MaxPool1D, GlobalMaxPooling1D, Dense, Dropout
from keras.callbacks import EarlyStopping
from keras.optimizers import Adam
import keras_tuner as kt
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix, ConfusionMatrixDisplay

# %%
EPOCHS=500
BATCH_SIZE=128
PATIENCE=5

# %% [markdown]
# # Load Preprocessed Data

# %%
data = pd.read_csv('data/fulltext_preprocessed_data.csv')
data['full_tokens'] = data['full_tokens'].apply(ast.literal_eval)
data.head()
# Out:
#                                            full_text  \
# 0  House Dem Aide: We Didn’t Even See Comey’s Let...
# 1  FLYNN: Hillary Clinton, Big Woman on Campus - ...
# 2  Why the Truth Might Get You Fired Why the Trut...
# 3  15 Civilians Killed In Single US Airstrike Hav...
# 4  Iranian woman jailed for fictional unpublished...
#
#                                          full_tokens  \
# 0  [house, aide, even, see, letter, jason, house,...
# 1  [hillary, clinton, big, woman, campus, ever, g...
# 2  [truth, might, get, fired, truth, might, get, ...
# 3  [single, single, rate, american, higher, engag...
# 4  [iranian, woman, fictional, unpublished, story...
#
#                                 full_text_lemmatized  label
# 0  house aide even see letter jason house aide ev...      1
# 1  hillary clinton big woman campus ever get feel...      0
# 2  truth might get fired truth might get fired oc...      1
# 3  single single rate american higher engaged act...      1
# ...

# %%
X = data['full_tokens']
y = data['label']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, stratify=y, random_state=42)

# %% [markdown]
# # Load Best Embeddings & Embedding Dimension, Best Input Max Length, and Tokenizer

# %%
with open('artifacts/embeddings_input_best_params.pkl', 'rb') as f:
    loaded_input_items = pickle.load(f)

# %%
EMBEDDING_DIM = loaded_input_items['hyperparams']['embedding_dim']
MAX_LEN = loaded_input_items['hyperparams']['max_len']

# %%
tokenizer = loaded_input_items['tokenizer']
embedding_matrix = loaded_input_items['embedding_matrix']

# %%
VOCAB_SIZE = len(tokenizer.word_index) + 1

# %%
print(EMBEDDING_DIM, MAX_LEN, VOCAB_SIZE)
# Out:
# 200 588 35756

# %% [markdown]
# # Create Input Data

# %% [markdown]
# ## Generating the numerical/index sequences

# %%
X_train_seq = tokenizer.texts_to_sequences(X_train)
X_test_seq = tokenizer.texts_to_sequences(X_test)

# %% [markdown]
# ## Padding the sequences

# %%
X_train_pad = pad_sequences(X_train_seq, maxlen=max_len, padding='post')
X_test_pad = pad_sequences(X_test_seq, maxlen=max_len, padding='post')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 X_train_pad = pad_sequences(X_train_seq, maxlen=max_len, padding='post')
#       2 X_test_pad = pad_sequences(X_test_seq, maxlen=max_len, padding='post')
#
# NameError: name 'max_len' is not defined

# %% [markdown]
# # Tuning CNN

# %%
def build_model(hp):
    model = Sequential()
    model.add(Input(shape=(max_len,)))
    model.add(Embedding(input_dim=vocab_size, output_dim=EMBEDDING_DIM,
                            weights=[embedding_matrix],
                            trainable=hp.Choice('embeddings_trainable', values=[True, False])))
    num_conv_layers = hp.Int('num_conv_layers', min_value=1, max_value=3, step=1)
    for i in range(1,num_conv_layers+1):
        if i>1:
            model.add(MaxPool1D(pool_size=2))
        model.add(Conv1D(filters=hp.Choice(f'conv{i}_filters', values=[64, 128, 256, 512]),
                             kernel_size=hp.Int(f'conv{i}_kernel_size', min_value=2, max_value=5, step=1), 
                             strides=1, padding='valid', activation='relu'))
    
    model.add(GlobalMaxPooling1D())
    
    num_dense_layers = hp.Int('num_dense_layers', min_value=1, max_value=3, step=1)
    for i in range(1,num_dense_layers+1):
        model.add(Dense(units=hp.Choice(f'dense{i}_units', values=[16, 32, 64, 128]), 
                            activation='relu'))
        model.add(Dropout(hp.Float(f'dense{i}dropout', min_value=0.2, max_value=0.5, step=0.1)))
    
    model.add(Dense(1, activation='sigmoid'))
    
    model.compile(optimizer=Adam(learning_rate=hp.Choice('learning_rate', values=[0.001, 0.005, 0.01, 0.05, 0.1])), 
                      loss='binary_crossentropy', 
                      metrics=['accuracy'])
    return model

# %%
tuner = kt.Hyperband(
    build_model, 
    objective='val_accuracy',
    max_epochs=EPOCHS,
    factor=3,
    directory='tuner_results',
    project_name='cnn')

# %%
tuner.search(X_train_pad, y_train,
             validation_split=0.2,
             epochs=EPOCHS, batch_size=BATCH_SIZE,
             verbose=1)

# %%
best_model = tuner.get_best_models(num_models=1)[0]
best_hp = tuner.get_best_hyperparameters(num_trials=1)[0]
print(best_hp.values())

# %%
best_loss, best_accuracy = best_model.evaluate(X_test_pad, y_test, verbose=0)
print("Best CNN Accuracy:", best_accuracy)
print("Best CNN Loss:", best_loss)

# %%
best_model.save('artifacts/tuned_cnn.keras')
